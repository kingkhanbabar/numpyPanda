# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel("xgraph")
plt.ylabel("ygraph")
# Out:
# Text(0, 0.5, 'ygraph')

# %%
#Subplot in matplotlib
# import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.plot(x,x)
plt.subplot(2,2,2)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,y)
plt.subplot(2,2,4)
plt.plot(x**5,y**2)
# plt.plot([1,2,3], [4,5,6])
# plt.show()

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.2,0.45,0.4,0.4])
axis2.plot(x,y)

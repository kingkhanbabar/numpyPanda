# %%
#reshapeing create a view not create a copy'''
""" Reshaping"""

import numpy as np
arr= np.array([1,2,3,4,5,6])
reshapearr = arr.reshape(2,3)
print(reshapearr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#.flattering->copy  .reval()->view

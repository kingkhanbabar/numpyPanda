# %%
import pandas as pd

data = {
    "Name": ["Amit", "Rahul", "Neha"],
    "Age": [20, 22, 21],
    "City": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age    City
# 0   Amit   20   Delhi
# 1  Rahul   22  Mumbai
# 2   Neha   21    Pune
